# %%
pip install langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 11.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 14.9 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [langchain-google-genai]e-genai]s]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show langchain-google-genai
# Out:
# Name: langchain-google-genai
# Version: 4.2.1
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/google
# Author:
# Author-email:
# License: MIT
# Location: /Users/sheikhfairoz/Desktop/projects/lang_env/lib/python3.14/site-packages
# Requires: filetype, google-genai, langchain-core, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
